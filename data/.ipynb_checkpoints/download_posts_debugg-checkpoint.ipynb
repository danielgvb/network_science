# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_links = pd.read_excel('db_prod.xlsx')
df_links.head()
# Out:
#    id                                               link  \
# 0   1           https://www.instagram.com/p/CzTyW00KYzC/
# 1   2           https://www.instagram.com/p/C0PzOJxhEv7/
# 2   3           https://www.instagram.com/p/CzxRQd0tbV6/
# 3   4  https://www.instagram.com/p/CzZIXBVMWdZ/?img_i...
# 4   5  https://www.instagram.com/p/CzZIXBVMWdZ/?img_i...
#
#    Objectify (yes or no)
# 0                    1.0
# 1                    0.0
# 2                    0.0
# 3                    1.0
# 4                    1.0

# %%
df_links.dropna(inplace = True)

# %%
links = df_links['link']
#links = links[0:10]

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
current_directory
# Specify the folder path you want to search for text files in
folder_path = current_directory + '\\downloaded_posts'

# List all files in the folder
files = os.listdir(folder_path)

# Filter out only the text files (files with a .txt extension)
txt_files = [file for file in files if file.endswith('.txt')]
len(txt_files)
# Out:
# 259

# %%
import os
# Folder to save the posts
download_folder = 'downloaded_posts'
os.makedirs(download_folder, exist_ok=True)
shortcodes = []
ids = df_links['id']
dict_ids_codes = {}
for link, id in zip(links, ids):
    shortcode = link.split('/')[-2]
    dict_ids_codes[id] = shortcode

# %%
dict_ids_codes
# Out:
# {1: 'CzTyW00KYzC',
#  2: 'C0PzOJxhEv7',
#  3: 'CzxRQd0tbV6',
#  4: 'CzZIXBVMWdZ',
#  5: 'CzZIXBVMWdZ',
#  6: 'CzZIXBVMWdZ',
#  7: 'CzZIXBVMWdZ',
#  8: 'CzT-taQMeDF',
#  9: 'CzRZny6MHUv',
#  10: 'CxqTYrTMHID',
#  11: 'CxqTYrTMHID',
#  12: 'Cxfl2VssMoN',
#  13: 'Cxfl2VssMoN',
#  14: 'CuzvxUFsba2',
#  15: 'CuzvxUFsba2',
#  16: 'CuwfGI6s9q9',
#  17: 'CtrYa6LM7ZD',
#  18: 'CtrYa6LM7ZD',
#  19: 'CtrYa6LM7ZD',
#  20: 'CsjS4NbMy1c',
#  21: 'CsRNN-us2lf',
#  22: 'CsRNN-us2lf',
#  23: 'CsRNN-us2lf',
#  24: 'CqLU0uiDeSZ',
#  25: 'CqLU0uiDeSZ',
#  26: 'Copm4TxsIVi',
#  27: 'CmFGPYkM5AQ',
#  28: 'Cll7fIRsuo2',
#  29: 'CiaXyUYsqcJ',
#  30: 'CfWb4Uvs0hp',
#  31: 'CfWb4Uvs0hp',
#  32: 'CUXm0ziMX_s',
#  33: 'CUXm0ziMX_s',
#  34: 'CS7G8jLCAr_',
#  35: 'CS12K0iMnl_',
#  36: 'CKMPYM2sVxd',
#  37: 'CKMNRR8spKS',
#  38: 'CHGcWB8DfNa',
#  39: 'CBTO1lXjrAA',
#  40: 'CBTO1lXjrAA',
#  41: 'CAJCsMvjDS_',
#  42: 'B_InZsOD0Aj',
#  43: 'B_InFhIjr9j',
#  44: 'B9XY-IjjDWt',
#  45: 'B9UltWvIDjA',
#  46: 'B8zBgZeD8bQ',
#  47: 'C0XtzX8PW6V',
#  48: 'C0UTXb0RHUw',
#  49: 'Cz745KtrB_n',
#  50: 'CztvKcKAvhR',
#  51: 'Czhgc_dvPnV',
#  52: 'CyzK_ClMLqG',
#  53: 'CyPbxl1MahD',
#  54: 'CxQfRCmgc2g',
#  55: 'CqxwuUMAh1P',
#  56: 'C0T94WpM4eT',
#  57: 'Cx-6Ob-MG1n',
#  58: 'CumW5lsMSPl',
#  59: 'CpQWgLfMAkS',
#  60: 'CopA32MMPj_',
#  61: 'CzvcjCvMlDb',
#  62: 'CzqudKKtpxl',
#  63: 'Czehr9KrCwj',
#  64: 'Cy3O-Yysc1v',
#  65: 'CywCd8iM03I',
#  66: 'CyAnd_uNwJ_',
#  67: 'Cxik4SuInww',
#  68: 'C0JuzUvMK2B',
#  69: 'CzlrsMDsFfc',
#  70: 'Cx8wSMqL1FR',
#  71: 'CxdGrHSxzSh',
#  72: 'Cxah4Q0upWQ',
#  73: 'CxNp5yItmJ9',
#  74: 'Cwpmx0rxH3z',
#  75: 'C0eCH7dKb3V',
#  76: 'C0SJdFFKC_G',
#  77: 'C0Q1XdhKULM',
#  78: 'C0LrQoEs2f_',
#  79: 'CyiGPWiqlba',
#  80: 'C0b7pbjscVJ',
#  81: 'C0CL6aJMqCi',
#  82: 'Cr0ativsXMr',
#  83: 'CpDATm-sGno',
#  84: 'C0LqfLopkod',
#  85: 'C0Gg3CiKkNY',
#  86: 'C0D8Eh9rayl',
#  87: 'Czyjr5XojbS',
#  88: 'CzeSHA3r_Pf',
#  89: 'C0UvM2UNU3w',
#  90: 'C0H-DQlNFD8',
#  91: 'C0H9dc8N_kZ',
#  92: 'C0EJQ7ztfXA',
#  93: 'C0WomKAI-BB',
#  94: 'C0J0FEwIZXN',
#  95: 'C0EbUh-ISrk',
#  96: 'Cz6WvlHIthf',
#  97: 'CyNkw4DI0Xi',
#  98: 'CyNkw4DI0Xi',
#  99: 'Czgv4QgPash',
#  100: 'CyfhUluMPiC',
#  101: 'CyqJBKxIC4c',
#  102: 'Cx-2O1IoFIx',
#  103: 'Cw5eSPJoA-p',
#  104: 'CyGl_1Wsjye',
#  105: 'Ct9GBxJs0kP',
#  106: 'CsJfj3cown4',
#  107: 'CZPwOJMI1OU',
#  108: 'Cjkwkh_tS7K',
#  109: 'Ci7zjVyK6a3',
#  110: 'CgUeah1qtWy',
#  111: 'CZXc563Lm0o',
#  112: 'CZR9-VSLu3e',
#  113: 'Cl6HMz8seZj',
#  114: 'CxdGrHSxzSh',
#  115: 'CxNp5yItmJ9',
#  116: 'CqbIxPiMwz_',
#  117: 'CqLy8FYtyz3',
#  118: 'CovGK0avP-P',
#  119: 'Cl_rmxVtLoJ',
#  120: 'CkJc1zCKo90',
#  121: 'CiFzsCMtJRq',
#  122: 'ChZfzysNnrf',
#  123: 'ChU4hHWN4tR',
#  124: 'ChFb1wnNtA7',
#  125: 'CgulNivq69s',
#  126: 'CedMvEzKkk4',
#  127: 'CcsciaFrGBX',
#  128: 'CZ48_ERok7n',
#  129: 'CYHp_v-tLBJ',
#  130: 'CYEb9bUIHuz',
#  131: 'CXtDIq3oueE',
#  132: 'CWn9ICCNqfm',
#  133: 'CUsrjjZIqBH',
#  134: 'CUDe3G9IBq5',
#  135: 'CTsTxMXI-1F',
#  136: 'C0ep0HMB_3p',
#  137: 'C0WZFxdv6yY',
#  138: 'C0UWpWvBYtw',
#  139: 'C0UCDN7MgPP',
#  140: 'C0MTo8aL1Qs',
#  141: 'C0JhHKVLk0J',
#  142: 'C0ElQ7HLOET',
#  143: 'Cz824fxLiuv',
#  144: 'Cz8ey7_L-Q5',
#  145: 'CzqnmFaPkX-',
#  146: 'Czld_aqhEau',
#  147: 'Czg2twNLU8O',
#  148: 'CzgUYx_CjJD',
#  149: 'CzdvomxpzT_',
#  150: 'CzbONHMIp0u',
#  151: 'CzEXpMYL5Pd',
#  152: 'Cy0i2bGO9xM',
#  153: 'CyvZVLAqFS5',
#  154: 'CyqTGcxv-zP',
#  155: 'Cylocs3BiS0',
#  156: 'CylGF32tNRY',
#  157: 'CyD1eAsBiWq',
#  158: 'CyBGX1VJKWB',
#  159: 'Cx_Ae0BJwP_',
#  160: 'CxcBxNxhLW9',
#  161: 'CxF0qL0JmG_',
#  162: 'CwK0Grss9GZ',
#  163: 'CwA1h-4sAXT',
#  164: 'Cv7XV00uJlc',
#  165: 'Cv4hYOArunp',
#  166: 'CvU5tkISsYh',
#  167: 'CvSU6cyptIu',
#  168: 'CvR84vTJqiH',
#  169: 'CvK0Q_0hFdU',
#  170: 'CvKcOsgtoIC',
#  171: 'CuzDWJoPr2N',
#  172: 'CuZhIfYJcy6',
#  173: 'CuUsJSKoPYA',
#  174: 'CuHVRHUSNqO',
#  175: 'Ct9g-_oLR6e',
#  176: 'CtzNzlBr-Gk',
#  177: 'Ctle5tULoaD',
#  178: 'CtgjEICpQPQ',
#  179: 'CtbjwOAhvm2',
#  180: 'CtOvNvCSh9h',
#  181: 'CtImrrJvZLr',
#  182: 'CtEVKuhSNtj',
#  183: 'CsyTmbJtRpi',
#  184: 'Csgf9ORJz8c',
#  185: 'Cz6mwpOKV6z',
#  186: 'Cz9m4zVRIDs',
#  187: 'Cxp3yuOMidv',
#  188: 'CthFX1otDyN',
#  189: 'CrjV6DiMMfQ',
#  190: 'CrT5Hdstyaj',
#  191: 'Co2gxs6Ik10',
#  192: 'Co2gxs6Ik10',
#  193: 'CljXn3BDpcn',
#  194: 'CkYQVReOym8',
#  195: 'CjN54aVh1HD',
#  196: 'CiaA_vNjl4d',
#  197: 'CdnkDKyjvLO',
#  198: 'CdYim_Ij0z1',
#  199: 'CPizZpNjDzT',
#  200: 'B3__d73i46x',
#  201: 'BmiLQlElqgG',
#  202: 'BkcQY6FlNcN',
#  203: 'BhePlPUljFR',
#  204: 'BZQS9fIFDjO',
#  205: 'BLDhgP7hg-h',
#  206: 'BC3N8eFRlpm',
#  207: '-PHbiexlr_',
#  208: 'CJEcAKrs-7C',
#  209: 'B-y2Fo8qcN_',
#  210: 'Bvi3R68ALJP',
#  211: 'BJn5LRbBpo8',
#  212: 'BBIHpekRlhD',
#  213: '4yqgDyxloK',
#  214: '3YO1o0Rlkt',
#  215: 'mrzAb-Rlkt',
#  216: 'fNO52Nxluy',
#  217: 'lzQl_gRlnD',
#  218: 'Cz1F2pkoGNW',
#  219: 'CzWFHoMICo0',
#  220: 'CyN2z-YoqT5',
#  221: 'CxX_6OqtqjQ',
#  222: 'CwuzOiwNJ2H',
#  223: 'CvzkyUDoTS6',
#  224: 'CvWz4j1IiyZ',
#  225: 'CtdtyVuNNNv',
#  226: 'CsIuLbisBLv',
#  227: 'Cr5YYyzs6Ot',
#  228: 'Cp9ttssIBGd',
#  229: 'C0bwbVxskqV',
#  230: 'C0eVJZTMOSm',
#  231: 'C0PNLV2Md0I',
#  232: 'C0Eq5_isMaO',
#  233: 'Cz6SMg6sDFK',
#  234: 'Czy_v6xRg4I',
#  235: 'CzZMjcYMP21',
#  236: 'CzTwO8_sfr3',
#  237: 'CyteauWxiPo',
#  238: 'CxxuB4TMKwh',
#  239: 'CzTyW00KYzC',
#  240: 'CvMQ-z-ONEU',
#  241: 'Cs_ddHKqyf8',
#  242: 'CsqzXdkKfbZ',
#  243: 'Cq0L6dZqGPu',
#  244: 'CoKT2D2Kg0G',
#  245: 'Cf_YGRgKs7h',
#  246: 'CdA4OLQqe46',
#  247: 'CbaED2oK-pA',
#  248: 'CYRbUHtquPw',
#  249: 'CYRbUHtquPw',
#  250: 'CWi3kD-q1xZ',
#  251: 'CUnA473KENK',
#  252: 'CSqqD7uqa4M',
#  253: 'CRRSZs6BswS',
#  254: 'CQQKyIuFRxT',
#  255: 'CIiZKTHHVmj',
#  256: 'Czq4TMwrlZo',
#  257: 'CzBtFadutfg',
#  258: 'CwdACiNvoNo',
#  259: 'CwFvBgNrriU',
#  260: 'CvfDNUBOZcs',
#  261: 'Ctt7Qe1ushu',
#  262: 'CryFoOGOBt5',
#  263: 'CrV02jtuXBt',
#  264: 'CswH7mVodab',
#  265: 'CeqjCb7I-wP',
#  266: 'CW6AeAVq3tJ',
#  267: 'COVXYFIh7YA',
#  269: 'C0Y8rSqMl8T',
#  270: 'C0MA5KQsLKS',
#  271: 'CztofkpMPOo',
#  272: 'C0jR0I8tGEl',
#  273: 'CzWZ6R6qdbl',
#  274: 'CyDCWb7K0mQ',
#  275: 'CxzwTV1gh88',
#  276: 'CuoYI__o4IZ',
#  277: 'Cra4qYsMi9C',
#  278: 'CrfngGbgTBF',
#  279: 'Cy3AwyyMlvd',
#  280: 'CystloQtc3B',
#  281: 'CxnMNwKsphQ',
#  282: 'Cu6q25Us_XC',
#  283: 'CtjBFvLtulX'}

# %%
import os
import json
import lzma

# Specify the directory you want to search
directory = 'downloaded_posts'
codes_dict = {}
# List all files ending with .xz in the specified directory
xz_files = [file for file in os.listdir(directory) if file.endswith('.xz')]

for file in xz_files:
    # Open and decompress the .xz file
    file_short = file.split('.')[0]
    file_path = directory + '/' + file
    with lzma.open(file_path, 'rt') as file:
        data = json.load(file)
        
    codes_dict[file_short] = data['node']['shortcode']

# %%
codes_dict
# Out:
# {'2013-10-08_12-40-36_UTC': 'fNO52Nxluy',
#  '2014-03-21_10-14-52_UTC': 'lzQl_gRlnD',
#  '2014-04-12_09-13-03_UTC': 'mrzAb-Rlkt',
#  '2015-06-01_07-45-08_UTC': '3YO1o0Rlkt',
#  '2015-07-06_10-38-30_UTC': '4yqgDyxloK',
#  '2015-11-18_18-26-59_UTC': '-PHbiexlr_',
#  '2016-01-29_14-48-24_UTC': 'BBIHpekRlhD',
#  '2016-03-12_18-19-07_UTC': 'BC3N8eFRlpm',
#  '2016-08-27_19-08-47_UTC': 'BJn5LRbBpo8',
#  '2016-10-02_09-12-04_UTC': 'BLDhgP7hg-h',
#  '2017-09-20_07-34-38_UTC': 'BZQS9fIFDjO',
#  '2018-04-12_13-45-37_UTC': 'BhePlPUljFR',
#  '2018-06-25_08-48-23_UTC': 'BkcQY6FlNcN',
#  '2018-08-16_09-01-47_UTC': 'BmiLQlElqgG',
#  '2019-03-28_08-08-59_UTC': 'Bvi3R68ALJP',
#  '2019-10-24_11-49-40_UTC': 'B3__d73i46x',
#  '2020-02-20_17-34-19_UTC': 'B8zBgZeD8bQ',
#  '2020-03-04_18-25-36_UTC': 'B9UltWvIDjA',
#  '2020-03-05_20-32-01_UTC': 'B9XY-IjjDWt',
#  '2020-04-10_08-57-20_UTC': 'B-y2Fo8qcN_',
#  '2020-04-18_19-49-32_UTC': 'B_InFhIjr9j',
#  '2020-04-18_19-52-18_UTC': 'B_InZsOD0Aj',
#  '2020-05-13_20-22-09_UTC': 'CAJCsMvjDS_',
#  '2020-06-11_15-52-05_UTC': 'CBTO1lXjrAA',
#  '2020-11-02_19-48-21_UTC': 'CHGcWB8DfNa',
#  '2020-12-08_12-50-40_UTC': 'CIiZKTHHVmj',
#  '2020-12-21_18-09-40_UTC': 'CJEcAKrs-7C',
#  '2021-01-18_15-06-15_UTC': 'CKMNRR8spKS',
#  '2021-01-18_15-24-40_UTC': 'CKMPYM2sVxd',
#  '2021-05-01_14-33-18_UTC': 'COVXYFIh7YA',
#  '2021-05-31_16-19-42_UTC': 'CPizZpNjDzT',
#  '2021-06-18_07-09-51_UTC': 'CQQKyIuFRxT',
#  '2021-07-13_14-07-03_UTC': 'CRRSZs6BswS',
#  '2021-08-17_07-06-12_UTC': 'CSqqD7uqa4M',
#  '2021-08-21_15-23-39_UTC': 'CS12K0iMnl_',
#  '2021-08-23_16-26-27_UTC': 'CS7G8jLCAr_',
#  '2021-09-11_19-01-17_UTC': 'CTsTxMXI-1F',
#  '2021-09-20_19-00-45_UTC': 'CUDe3G9IBq5',
#  '2021-09-28_14-35-09_UTC': 'CUXm0ziMX_s',
#  '2021-10-04_14-11-30_UTC': 'CUnA473KENK',
#  '2021-10-06_19-00-32_UTC': 'CUsrjjZIqBH',
#  '2021-11-21_16-35-50_UTC': 'CWi3kD-q1xZ',
#  '2021-11-23_16-00-39_UTC': 'CWn9ICCNqfm',
#  '2021-11-30_16-16-11_UTC': 'CW6AeAVq3tJ',
#  '2021-12-20_12-00-45_UTC': 'CXtDIq3oueE',
#  '2021-12-29_14-00-12_UTC': 'CYEb9bUIHuz',
#  '2021-12-30_20-00-35_UTC': 'CYHp_v-tLBJ',
#  '2022-01-03_15-04-42_UTC': 'CYRbUHtquPw',
#  '2022-01-27_20-00-18_UTC': 'CZPwOJMI1OU',
#  '2022-01-28_16-38-57_UTC': 'CZR9-VSLu3e',
#  '2022-01-30_19-45-26_UTC': 'CZXc563Lm0o',
#  '2022-02-12_20-00-41_UTC': 'CZ48_ERok7n',
#  '2022-03-22_13-08-51_UTC': 'CbaED2oK-pA',
#  '2022-04-23_13-00-27_UTC': 'CcsciaFrGBX',
#  '2022-05-01_11-27-10_UTC': 'CdA4OLQqe46',
#  '2022-05-10_16-00-12_UTC': 'CdYim_Ij0z1',
#  '2022-05-16_12-01-17_UTC': 'CdnkDKyjvLO',
#  '2022-06-06_07-56-33_UTC': 'CedMvEzKkk4',
#  '2022-06-11_12-21-34_UTC': 'CeqjCb7I-wP',
#  '2022-06-28_13-25-36_UTC': 'CfWb4Uvs0hp',
#  '2022-07-14_11-01-25_UTC': 'Cf_YGRgKs7h',
#  '2022-07-22_15-40-40_UTC': 'CgUeah1qtWy',
#  '2022-08-01_19-00-18_UTC': 'CgulNivq69s',
#  '2022-08-10_16-00-57_UTC': 'ChFb1wnNtA7',
#  '2022-08-16_16-00-09_UTC': 'ChU4hHWN4tR',
#  '2022-08-18_11-00-27_UTC': 'ChZfzysNnrf',
#  '2022-09-04_16-00-44_UTC': 'CiFzsCMtJRq',
#  '2022-09-12_12-21-50_UTC': 'CiaA_vNjl4d',
#  '2022-09-12_15-40-58_UTC': 'CiaXyUYsqcJ',
#  '2022-09-25_15-18-32_UTC': 'Ci7zjVyK6a3',
#  '2022-10-02_16-00-13_UTC': 'CjN54aVh1HD',
#  '2022-10-11_13-01-20_UTC': 'Cjkwkh_tS7K',
#  '2022-10-25_19-00-50_UTC': 'CkJc1zCKo90',
#  '2022-10-31_13-00-12_UTC': 'CkYQVReOym8',
#  '2022-11-29_17-06-53_UTC': 'CljXn3BDpcn',
#  '2022-11-30_16-58-45_UTC': 'Cll7fIRsuo2',
#  '2022-12-08_13-05-55_UTC': 'Cl6HMz8seZj',
#  '2023-11-11_12-00-25_UTC': 'CzgUYx_CjJD',
#  '2023-11-11_16-00-39_UTC': 'Czgv4QgPash',
#  '2023-11-11_17-00-23_UTC': 'Czg2twNLU8O',
#  '2023-11-11_23-05-05_UTC': 'Czhgc_dvPnV',
#  '2023-11-13_12-00-32_UTC': 'Czld_aqhEau',
#  '2023-11-13_14-00-20_UTC': 'CzlrsMDsFfc',
#  '2023-11-15_12-00-40_UTC': 'CzqnmFaPkX-',
#  '2023-11-15_13-00-37_UTC': 'CzqudKKtpxl',
#  '2023-11-15_14-26-38_UTC': 'Czq4TMwrlZo',
#  '2023-11-16_16-06-14_UTC': 'CztofkpMPOo',
#  '2023-11-16_17-04-31_UTC': 'CztvKcKAvhR',
#  '2023-11-17_09-00-20_UTC': 'CzvcjCvMlDb',
#  '2023-11-18_02-00-09_UTC': 'CzxRQd0tbV6',
#  '2023-11-18_14-00-26_UTC': 'Czyjr5XojbS',
#  '2023-11-18_18-05-39_UTC': 'Czy_v6xRg4I',
#  '2023-11-19_13-37-28_UTC': 'Cz1F2pkoGNW',
#  '2023-11-21_14-01-31_UTC': 'Cz6SMg6sDFK',
#  '2023-11-21_14-41-15_UTC': 'Cz6WvlHIthf',
#  '2023-11-21_17-01-14_UTC': 'Cz6mwpOKV6z',
#  '2023-11-22_04-58-54_UTC': 'Cz745KtrB_n',
#  '2023-11-22_10-30-06_UTC': 'Cz8ey7_L-Q5',
#  '2023-11-22_14-00-35_UTC': 'Cz824fxLiuv',
#  '2023-11-22_21-00-08_UTC': 'Cz9m4zVRIDs',
#  '2023-11-24_15-40-32_UTC': 'C0CL6aJMqCi',
#  '2023-11-25_08-00-36_UTC': 'C0D8Eh9rayl',
#  '2023-11-25_09-55-53_UTC': 'C0EJQ7ztfXA',
#  '2023-11-25_12-33-40_UTC': 'C0EbUh-ISrk',
#  '2023-11-25_14-00-33_UTC': 'C0ElQ7HLOET',
#  '2023-11-25_14-49-51_UTC': 'C0Eq5_isMaO',
#  '2023-11-26_08-00-34_UTC': 'C0Gg3CiKkNY',
#  '2023-11-27_12-00-28_UTC': 'C0JhHKVLk0J',
#  '2023-11-27_14-00-10_UTC': 'C0JuzUvMK2B',
#  '2023-11-27_14-46-12_UTC': 'C0J0FEwIZXN',
#  '2023-11-28_08-00-52_UTC': 'C0LqfLopkod',
#  '2023-11-28_08-07-37_UTC': 'C0LrQoEs2f_',
#  '2023-11-28_11-16-39_UTC': 'C0MA5KQsLKS',
#  '2023-11-28_14-00-28_UTC': 'C0MTo8aL1Qs',
#  '2023-11-29_17-01-43_UTC': 'C0PNLV2Md0I',
#  '2023-11-29_22-34-09_UTC': 'C0PzOJxhEv7',
#  '2023-11-30_08-12-08_UTC': 'C0Q1XdhKULM',
#  '2023-11-30_20-26-54_UTC': 'C0SJdFFKC_G',
#  '2023-12-01_13-24-15_UTC': 'C0T94WpM4eT',
#  '2023-12-01_14-00-41_UTC': 'C0UCDN7MgPP',
#  '2023-12-01_16-32-00_UTC': 'C0UTXb0RHUw',
#  '2023-12-01_17-00-40_UTC': 'C0UWpWvBYtw',
#  '2023-12-02_12-00-30_UTC': 'C0WZFxdv6yY',
#  '2023-12-02_14-15-59_UTC': 'C0WomKAI-BB',
#  '2023-12-03_00-20-44_UTC': 'C0XtzX8PW6V',
#  '2023-12-03_11-49-56_UTC': 'C0Y8rSqMl8T',
#  '2023-12-04_14-00-37_UTC': 'C0bwbVxskqV',
#  '2023-12-04_15-38-40_UTC': 'C0b7pbjscVJ',
#  '2023-12-05_11-13-44_UTC': 'C0eCH7dKb3V',
#  '2023-12-05_13-59-58_UTC': 'C0eVJZTMOSm',
#  '2023-12-05_17-00-34_UTC': 'C0ep0HMB_3p',
#  '2023-12-07_12-07-03_UTC': 'C0jR0I8tGEl'}

# %% [markdown]
# ### Turn to table and merge

# %%
df_long_codes = pdf = pd.DataFrame(list(codes_dict.items()), columns=['Long', 'Short'])
df_long_codes.head()
# Out:
#                       Long       Short
# 0  2013-10-08_12-40-36_UTC  fNO52Nxluy
# 1  2014-03-21_10-14-52_UTC  lzQl_gRlnD
# 2  2014-04-12_09-13-03_UTC  mrzAb-Rlkt
# 3  2015-06-01_07-45-08_UTC  3YO1o0Rlkt
# 4  2015-07-06_10-38-30_UTC  4yqgDyxloK

# %%
df_short_codes = pdf = pd.DataFrame(list(dict_ids_codes.items()), columns=['id', 'Short'])
df_short_codes.head()
# Out:
#    id        Short
# 0   1  CzTyW00KYzC
# 1   2  C0PzOJxhEv7
# 2   3  CzxRQd0tbV6
# 3   4  CzZIXBVMWdZ
# 4   5  CzZIXBVMWdZ

# %%
df_merge = df_short_codes.merge(df_long_codes, how='left', on = 'Short')
print(len(df_merge))
# Out:
# 282

# %%
df_merge
# Out:
#       id        Short                     Long
# 0      1  CzTyW00KYzC  2023-11-06_15-12-10_UTC
# 1      2  C0PzOJxhEv7  2023-11-29_22-34-09_UTC
# 2      3  CzxRQd0tbV6  2023-11-18_02-00-09_UTC
# 3      4  CzZIXBVMWdZ  2023-11-08_17-00-38_UTC
# 4      5  CzZIXBVMWdZ  2023-11-08_17-00-38_UTC
# ..   ...          ...                      ...
# 277  279  Cy3AwyyMlvd  2023-10-26_11-00-25_UTC
# 278  280  CystloQtc3B  2023-10-22_11-00-18_UTC
# 279  281  CxnMNwKsphQ  2023-09-25_11-00-55_UTC
# 280  282  Cu6q25Us_XC  2023-07-20_11-00-38_UTC
# 281  283  CtjBFvLtulX  2023-06-16_10-01-12_UTC
#
# [282 rows x 3 columns]

# %%
nan_counts = df_merge.isna().sum()

# Display the count of NaNs per column
print(nan_counts)
# Out:
# id       0
# Short    0
# Long     3
# dtype: int64

# %%
df_final = df_merge.merge(df_links, how='left', on = 'id')
df_final.to_excel('dataframe_codigos.xlsx')
