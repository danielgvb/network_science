# %%
import instaloader

import os
import re
import shutil

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

download_dir = os.path.join("data",'raw')
os.makedirs(download_dir, exist_ok=True)

failed_posts = []

loader = instaloader.Instaloader()
# loader.load_session_from_file('rafadimare')
# Out:
# C:\Users\rdm42\anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# C:\Users\rdm42\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
xl_path = os.path.join('data','resources','database.xlsx')

already_downloaded = os.listdir(download_dir)

with pd.ExcelFile(xl_path) as xl:
    df = xl.parse() \
           .drop(columns=['id']) \
           .dropna(subset=['link']) \
           .eval("post_code = link.str.split('/').str[-2]") \
           .drop_duplicates(subset=['post_code']) \
           .rename(columns={'Objectify (yes or no)':'objectifies'})
    
pending = df.query("~post_code.isin(@already_downloaded)")
pending

# Check not to drop the row which contains objectify
# Check for missing values on objectify column

# df.query("post_code.isin(@already_downloaded)").post_code.to_clipboard(index=False, header=False)
# Out:
#                                                   link  objectifies  \
# 88   https://www.instagram.com/p/C0UvM2UNU3w/?img_i...          0.0
# 89   https://www.instagram.com/p/C0H-DQlNFD8/?img_i...          1.0
# 90   https://www.instagram.com/p/C0H9dc8N_kZ/?img_i...          1.0
# 170  https://www.instagram.com/p/CuzDWJoPr2N/?utm_s...          1.0
# 171  https://www.instagram.com/p/CuZhIfYJcy6/?utm_s...          1.0
# ..                                                 ...          ...
# 277  https://www.instagram.com/p/CrfngGbgTBF/?utm_s...          1.0
# 278  https://www.instagram.com/p/Cy3AwyyMlvd/?utm_s...          1.0
# 279  https://www.instagram.com/p/CystloQtc3B/?utm_s...          0.0
# 280  https://www.instagram.com/p/CxnMNwKsphQ/?utm_s...          1.0
# 281  https://www.instagram.com/p/Cu6q25Us_XC/?utm_s...          1.0
#
#        post_code
# 88   C0UvM2UNU3w
# 89   C0H-DQlNFD8
# 90   C0H9dc8N_kZ
# 170  CuzDWJoPr2N
# 171  CuZhIfYJcy6
# ..           ...
# 277  CrfngGbgTBF
# 278  Cy3AwyyMlvd
# 279  CystloQtc3B
# 280  CxnMNwKsphQ
# 281  Cu6q25Us_XC
#
# [105 rows x 3 columns]

# %%
# for post_code in pending.post_code.tolist():
    
#     try:    
#         print(f"\tSTART: {pd.Timestamp.now():%H : %M : %S}")
#         print('\t\t'+post_code)
        
#         post = instaloader.Post.from_shortcode(loader.context, post_code)
#         loader.download_post(post, target=post_code)

#         print(f"\t\tEND: {pd.Timestamp.now():%H : %M : %S}")
#         print(f"\n\nPost {post_code} downloaded successfully" + "\n" + "-"*100 + '\n'*2)
#         shutil.move(post_code, download_dir)
        
#     except instaloader.exceptions.InstaloaderException as e:
#         print(f"Error: {e}")
#         failed_posts.append((post_code,e))
        
#     time.sleep(5)

# %%
# # Simple code to retrieve comments

# post_code = "CW6AeAVq3tJ"
# post = instaloader.Post.from_shortcode(loader.context, post_code)
# for comment in post.get_comments():
#     print(comment)

# %% [markdown]
# # Lectura de captions

# %%
captions = []

for post_code in os.listdir(download_dir):
    
    post_data_path = os.path.join(download_dir,post_code)

    txt_file = [file for file in os.listdir(post_data_path) if file.endswith('.txt')][0]
    caption_path = os.path.join(post_data_path,txt_file)

    with open(caption_path,'r',encoding='utf-8') as f:
        caption = f.read().strip()
        
    captions.append((post_code, caption))
    
captions = pd.DataFrame(captions, columns=['post_code','caption'])

# captions.head(5)
# df.merge(captions,on='post_code',how='inner')

# %% [markdown]
# # Lectura de metadata

# %%
import json
import lzma

additional_data = []

for i,post_code in enumerate(os.listdir(download_dir)):

    post_path = os.path.join(download_dir,post_code)

    metadata_path = os.path.join(post_path,
                                 [file for file in os.listdir(post_path) if file.endswith('.json.xz')][0])
    
    with lzma.open(metadata_path, 'rt') as file:
        data_dict = json.load(file)
        
    user = data_dict['node']['owner']['username']
    likes = data_dict['node']['edge_media_preview_like']['count']

    additional_data.append((post_code,user,likes))

addtional_data = pd.DataFrame(additional_data, columns=['post_code','user','likes'])

# addtional_data.merge(df).groupby('user').agg({'objectifies':'mean'}).sort_values('objectifies')

# %% [markdown]
# # Writing on file

# %%
output_file = f"posts_data_{pd.Timestamp.now():%Y%m%d_%H%M}.csv"
output_path = os.path.join('data','standardized',output_file)

df.merge(captions).merge(addtional_data).to_csv(output_path,index=False,encoding='UTF-16')

# %%
pd.read_csv(output_path,encoding='UTF-16')
# Out:
#                                                   link  objectifies  \
# 0             https://www.instagram.com/p/CzTyW00KYzC/          1.0
# 1             https://www.instagram.com/p/C0PzOJxhEv7/          0.0
# 2             https://www.instagram.com/p/CzxRQd0tbV6/          0.0
# 3    https://www.instagram.com/p/CzZIXBVMWdZ/?img_i...          1.0
# 4    https://www.instagram.com/p/CzT-taQMeDF/?img_i...          1.0
# ..                                                 ...          ...
# 153  https://www.instagram.com/p/CdYim_Ij0z1/?igshi...          1.0
# 154  https://www.instagram.com/p/-PHbiexlr_/?igshid...          1.0
# 155  https://www.instagram.com/p/BJn5LRbBpo8/?igshi...          1.0
# 156  https://www.instagram.com/p/lzQl_gRlnD/?igshid...          1.0
# 157  https://www.instagram.com/p/CtjBFvLtulX/?utm_s...          0.0
#
#        post_code                                            caption  \
# 0    CzTyW00KYzC  A golden fantasy. #rabanneHM launches 9 Novemb...
# 1    C0PzOJxhEv7  El denim, ¡siempre el protagonista en tus look...
# 2    CzxRQd0tbV6  Fresh goodies 🫶\n\n¿Qué tal este look para est...
# 3    CzZIXBVMWdZ  ”GUIRLANDE” with @kendalljenner\nThe holiday c...
# 4    CzT-taQMeDF  “GUIRLANDE” with @kendalljenner\nThe holiday c...
# ..           ...                                                ...
# 153  CdYim_Ij0z1  For @voguemagazine’s June/July cover @dualipa ...
# 154   -PHbiexlr_  Stunning Mariana Rodriguez in #amencouture. Se...
# 155  BJn5LRbBpo8  Amen Couture Flower Body on @playboy_russia ! ...
# 156   lzQl_gRlnD  Regram @nimabenati #amenstyle #amen #fashion #...
# 157  CtjBFvLtulX  Inspired by Scandinavian history, folk traditi...
#
#           user   likes
# 0           hm   10278
# 1    tennis_sa      85
# 2    tennis_sa     471
# 3    jacquemus  230620
# 4    jacquemus  376238
# ..         ...     ...
# 153      prada   36488
# 154  amenstyle     106
# 155  amenstyle     290
# 156  amenstyle     374
# 157    maxmara    7252
#
# [158 rows x 6 columns]
