# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_face = pd.read_excel('../0_data/dataframe_face_detection.xlsx')
df_face.head()
# Out:
#                           Long  Face
# 0  2015-11-18_18-26-59_UTC.jpg     1
# 1  2015-06-01_07-45-08_UTC.jpg     1
# 2  2015-07-06_10-38-30_UTC.jpg     1
# 3  2020-04-10_08-57-20_UTC.jpg     0
# 4  2019-10-24_11-49-40_UTC.jpg     1

# %%
df_skin = pd.read_excel('../0_data/dataframe_skin_pct.xlsx')
df_skin.head()
# Out:
#                           Long  Skin_pct
# 0  2015-11-18_18-26-59_UTC.jpg  0.042849
# 1  2015-06-01_07-45-08_UTC.jpg  0.491443
# 2  2015-07-06_10-38-30_UTC.jpg  0.133582
# 3  2020-04-10_08-57-20_UTC.jpg  0.258619
# 4  2019-10-24_11-49-40_UTC.jpg  0.888304

# %%
df_features = df_face.merge(df_skin, how = 'inner', on ='Long')
df_features.isna().any()
# Out:
# Long        False
# Face        False
# Skin_pct    False
# dtype: bool

# %%
df_features['Long'] = df_features['Long'].apply(lambda x: x.split('.')[0])

# %%
df_text = pd.read_excel('../0_data/pictures_captions_autocaptions.xlsx')
df_final = df_features.merge(df_text, how = 'right', on='Long')
df_final.isna().any()
# Out:
# Long                     False
# Face                     False
# Skin_pct                 False
# Auto_caption             False
# id                        True
# Short                     True
# link                      True
# Objectify (yes or no)     True
# caption                   True
# dtype: bool

# %%
df_final
# Out:
#                           Long  Face  Skin_pct  \
# 0      2015-11-18_18-26-59_UTC     1  0.042849
# 1      2015-06-01_07-45-08_UTC     1  0.491443
# 2      2015-07-06_10-38-30_UTC     1  0.133582
# 3      2020-04-10_08-57-20_UTC     0  0.258619
# 4      2019-10-24_11-49-40_UTC     1  0.888304
# ..                         ...   ...       ...
# 759  2023-11-08_17-37-17_UTC_4     1  0.030407
# 760  2023-11-08_17-37-17_UTC_5     0  0.022535
# 761    2013-10-08_12-40-36_UTC     1  0.244262
# 762    2014-03-21_10-14-52_UTC     1  0.220332
# 763    2014-04-12_09-13-03_UTC     1  0.372959
#
#                                           Auto_caption     id        Short  \
# 0    a picture of a woman with long black hair sits...  207.0   -PHbiexlr_
# 1    a picture of a woman with black hair and a bla...  214.0   3YO1o0Rlkt
# 2    a picture of a woman with black hair and a bla...  213.0   4yqgDyxloK
# 3    a picture of a woman wearing a black jacket an...  209.0  B-y2Fo8qcN_
# 4    a picture of a woman in a red dress sits on a ...  200.0  B3__d73i46x
# ..                                                 ...    ...          ...
# 759  a picture of a woman in a black coat and sungl...  235.0  CzZMjcYMP21
# 760  a picture of a woman with brown hair wearing a...  235.0  CzZMjcYMP21
# 761  a picture of a woman with black hair and a bar...  216.0   fNO52Nxluy
# 762  a picture of a young woman with long brown hai...  217.0   lzQl_gRlnD
# 763  a picture of a group of beautiful women, dress...  215.0   mrzAb-Rlkt
#
#                                                   link  Objectify (yes or no)  \
# 0    https://www.instagram.com/p/-PHbiexlr_/?igshid...                    1.0
# 1    https://www.instagram.com/p/3YO1o0Rlkt/?igshid...                    1.0
# 2    https://www.instagram.com/p/4yqgDyxloK/?igshid...                    1.0
# 3    https://www.instagram.com/p/B-y2Fo8qcN_/?igshi...                    1.0
# 4    https://www.instagram.com/p/B3__d73i46x/?igshi...                    1.0
# ..                                                 ...                    ...
# 759  https://www.instagram.com/p/CzZMjcYMP21/?utm_s...                    0.0
# 760  https://www.instagram.com/p/CzZMjcYMP21/?utm_s...                    0.0
# 761  https://www.instagram.com/p/fNO52Nxluy/?igshid...                    1.0
# 762  https://www.instagram.com/p/lzQl_gRlnD/?igshid...                    1.0
# 763  https://www.instagram.com/p/mrzAb-Rlkt/?igshid...                    1.0
#
#                                                caption
# 0    Stunning Mariana Rodriguez in #amencouture. Se...
# 1    @emastokholma in Amen embroidered #dress from ...
# 2    Stunning DJ @emastokholma wears all over paill...
# 3    Crystal Pumps ✨ #AmenStyle #AmenPreSpring20 #A...
# 4    Discover our FW19 Collection on amenstyle.com ...
# ..                                                 ...
# 759  This season must-have. @fashionhurricanebyv in...
# 760  This season must-have. @fashionhurricanebyv in...
# 761  Valentina Vignali looks explosive in a preciou...
# 762  Regram @nimabenati #amenstyle #amen #fashion #...
# 763        RG @nimabenati #amencouture amenstyle.com\n
#
# [764 rows x 9 columns]

# %%
# Now, to find and display rows with NaN values
rows_with_nans = df_final[df_final.isna().any(axis=1)]
rows_with_nans
# Out:
#                         Long  Face  Skin_pct  \
# 218  2021-03-29_12-23-06_UTC     1  0.102008
#
#                                           Auto_caption  id Short link  \
# 218  a picture of a woman with long brown hair wear... NaN   NaN  NaN
#
#      Objectify (yes or no) caption
# 218                    NaN     NaN

# %%
df_final = df_final.dropna().reset_index(drop = True)
df_final
# Out:
#                           Long  Face  Skin_pct  \
# 0      2015-11-18_18-26-59_UTC     1  0.042849
# 1      2015-06-01_07-45-08_UTC     1  0.491443
# 2      2015-07-06_10-38-30_UTC     1  0.133582
# 3      2020-04-10_08-57-20_UTC     0  0.258619
# 4      2019-10-24_11-49-40_UTC     1  0.888304
# ..                         ...   ...       ...
# 758  2023-11-08_17-37-17_UTC_4     1  0.030407
# 759  2023-11-08_17-37-17_UTC_5     0  0.022535
# 760    2013-10-08_12-40-36_UTC     1  0.244262
# 761    2014-03-21_10-14-52_UTC     1  0.220332
# 762    2014-04-12_09-13-03_UTC     1  0.372959
#
#                                           Auto_caption     id        Short  \
# 0    a picture of a woman with long black hair sits...  207.0   -PHbiexlr_
# 1    a picture of a woman with black hair and a bla...  214.0   3YO1o0Rlkt
# 2    a picture of a woman with black hair and a bla...  213.0   4yqgDyxloK
# 3    a picture of a woman wearing a black jacket an...  209.0  B-y2Fo8qcN_
# 4    a picture of a woman in a red dress sits on a ...  200.0  B3__d73i46x
# ..                                                 ...    ...          ...
# 758  a picture of a woman in a black coat and sungl...  235.0  CzZMjcYMP21
# 759  a picture of a woman with brown hair wearing a...  235.0  CzZMjcYMP21
# 760  a picture of a woman with black hair and a bar...  216.0   fNO52Nxluy
# 761  a picture of a young woman with long brown hai...  217.0   lzQl_gRlnD
# 762  a picture of a group of beautiful women, dress...  215.0   mrzAb-Rlkt
#
#                                                   link  Objectify (yes or no)  \
# 0    https://www.instagram.com/p/-PHbiexlr_/?igshid...                    1.0
# 1    https://www.instagram.com/p/3YO1o0Rlkt/?igshid...                    1.0
# 2    https://www.instagram.com/p/4yqgDyxloK/?igshid...                    1.0
# 3    https://www.instagram.com/p/B-y2Fo8qcN_/?igshi...                    1.0
# 4    https://www.instagram.com/p/B3__d73i46x/?igshi...                    1.0
# ..                                                 ...                    ...
# 758  https://www.instagram.com/p/CzZMjcYMP21/?utm_s...                    0.0
# 759  https://www.instagram.com/p/CzZMjcYMP21/?utm_s...                    0.0
# 760  https://www.instagram.com/p/fNO52Nxluy/?igshid...                    1.0
# 761  https://www.instagram.com/p/lzQl_gRlnD/?igshid...                    1.0
# 762  https://www.instagram.com/p/mrzAb-Rlkt/?igshid...                    1.0
#
#                                                caption
# 0    Stunning Mariana Rodriguez in #amencouture. Se...
# 1    @emastokholma in Amen embroidered #dress from ...
# 2    Stunning DJ @emastokholma wears all over paill...
# 3    Crystal Pumps ✨ #AmenStyle #AmenPreSpring20 #A...
# 4    Discover our FW19 Collection on amenstyle.com ...
# ..                                                 ...
# 758  This season must-have. @fashionhurricanebyv in...
# 759  This season must-have. @fashionhurricanebyv in...
# 760  Valentina Vignali looks explosive in a preciou...
# 761  Regram @nimabenati #amenstyle #amen #fashion #...
# 762        RG @nimabenati #amencouture amenstyle.com\n
#
# [763 rows x 9 columns]
