# %% [markdown]
# # **Import libraries**

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import nltk
import matplotlib.pyplot as plt
import datetime
from datetime import date
import time
import pickle

# %% [markdown]
# # **Load functions for data cleaning**

# %%
# %run ../labs/cleaning_mod.py
# Out:
# Requirement already satisfied: emoji in c:\users\danie\anaconda3\envs\ds_master\lib\site-packages (2.9.0)
# Requirement already satisfied: contractions in c:\users\danie\anaconda3\envs\ds_master\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\danie\anaconda3\envs\ds_master\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\danie\anaconda3\envs\ds_master\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in c:\users\danie\anaconda3\envs\ds_master\lib\site-packages (from textsearch>=0.0.21->contractions) (2.0.0)
# Requirement already satisfied: autocorrect in c:\users\danie\anaconda3\envs\ds_master\lib\site-packages (2.6.1)
# Requirement already satisfied: unidecode in c:\users\danie\anaconda3\envs\ds_master\lib\site-packages (1.2.0)

# %% [markdown]
# # Load Data
# At the picture level

# %%
df = pd.read_excel('../0_data/silver/6_data_silver_short.xlsx')
df.head()
# Out:
#                                             post_dir  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                         Auto_caption  \
# 0  the picture contains a woman with long brown h...
# 1  the picture contains a woman with long brown h...
# 2  the picture contains a woman with long brown h...
# 3  the picture contains a woman with long brown h...
# 4  the picture contains a woman with long brown h...
#
#                                                posts  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                              caption  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             All_text  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             img_path  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                         img_name        short       user  objectifies
# 0  2022-05-30_15-43-56_UTC_3.jpg  CeMAqJ6M8dN  jacquemus            1
# 1  2022-05-30_15-43-56_UTC_4.jpg  CeMAqJ6M8dN  jacquemus            1
# 2  2022-05-30_15-43-56_UTC_5.jpg  CeMAqJ6M8dN  jacquemus            1
# 3  2022-05-30_15-43-56_UTC_2.jpg  CeMAqJ6M8dN  jacquemus            0
# 4  2022-05-30_15-43-56_UTC_1.jpg  CeMAqJ6M8dN  jacquemus            1

# %% [markdown]
# # **Clean text**

# %% [markdown]
# First lets clean the Image processing instruction 'the picture contains'

# %%
df['Auto_caption'] = df['Auto_caption'].apply(lambda x: x.replace('the picture contains ',''))
df['All_text'] = df['All_text'].apply(lambda x: x.replace('the picture contains ',''))
df.head()
# Out:
#                                             post_dir  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                         Auto_caption  \
# 0  a woman with long brown hair sitting on a moto...
# 1  a woman with long brown hair sitting on a moto...
# 2  a woman with long brown hair sitting on a moto...
# 3  a woman with long brown hair sitting on a moto...
# 4  a woman with long brown hair sitting on a moto...
#
#                                                posts  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                              caption  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             All_text  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             img_path  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                         img_name        short       user  objectifies
# 0  2022-05-30_15-43-56_UTC_3.jpg  CeMAqJ6M8dN  jacquemus            1
# 1  2022-05-30_15-43-56_UTC_4.jpg  CeMAqJ6M8dN  jacquemus            1
# 2  2022-05-30_15-43-56_UTC_5.jpg  CeMAqJ6M8dN  jacquemus            1
# 3  2022-05-30_15-43-56_UTC_2.jpg  CeMAqJ6M8dN  jacquemus            0
# 4  2022-05-30_15-43-56_UTC_1.jpg  CeMAqJ6M8dN  jacquemus            1

# %%
# join caption and autocaption and user
df['All_text'] = df['user'] + ' ' + df['All_text']
df.head()
# Out:
#                                             post_dir  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                         Auto_caption  \
# 0  a woman with long brown hair sitting on a moto...
# 1  a woman with long brown hair sitting on a moto...
# 2  a woman with long brown hair sitting on a moto...
# 3  a woman with long brown hair sitting on a moto...
# 4  a woman with long brown hair sitting on a moto...
#
#                                                posts  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                              caption  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             All_text  \
# 0  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 1  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 2  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 3  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 4  jacquemus Sydney in Hawai’i at night by Tom\n@...
#
#                                             img_path  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                         img_name        short       user  objectifies
# 0  2022-05-30_15-43-56_UTC_3.jpg  CeMAqJ6M8dN  jacquemus            1
# 1  2022-05-30_15-43-56_UTC_4.jpg  CeMAqJ6M8dN  jacquemus            1
# 2  2022-05-30_15-43-56_UTC_5.jpg  CeMAqJ6M8dN  jacquemus            1
# 3  2022-05-30_15-43-56_UTC_2.jpg  CeMAqJ6M8dN  jacquemus            0
# 4  2022-05-30_15-43-56_UTC_1.jpg  CeMAqJ6M8dN  jacquemus            1

# %%
df['All_text'] = df['All_text'].astype(str)
df['Auto_caption'] = df['Auto_caption'].astype(str)
df['caption'] = df['caption'].astype(str)

# %% [markdown]
# All text

# %%
# superficial cleaning
df['text_sup_clean'] = df['All_text'].apply(superficial_cleaning)

# deep cleaning
POS_KEEP = ["ADJ","ADV","NOUN","PROPN","VERB","NUM"] # we do not include "PRON"
df['text_deep_clean'] = df['text_sup_clean'].apply(deep_cleaning)
df['text_deep_clean_pos'] = df['text_sup_clean'].apply(deep_cleaning_pos)

# extract hashtags (if present)
df['hashtags'] = df['All_text'].apply(get_hashtags)

# display the result
df.head()
# Out:
# C:\Users\danie\Documents\GitHub\network_science\labs\cleaning_mod.py:156: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(selftext, "html.parser")
#                                             post_dir  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                         Auto_caption  \
# 0  a woman with long brown hair sitting on a moto...
# 1  a woman with long brown hair sitting on a moto...
# 2  a woman with long brown hair sitting on a moto...
# 3  a woman with long brown hair sitting on a moto...
# 4  a woman with long brown hair sitting on a moto...
#
#                                                posts  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                              caption  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             All_text  \
# 0  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 1  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 2  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 3  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 4  jacquemus Sydney in Hawai’i at night by Tom\n@...
#
#                                             img_path  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                         img_name        short       user  objectifies  \
# 0  2022-05-30_15-43-56_UTC_3.jpg  CeMAqJ6M8dN  jacquemus            1
# 1  2022-05-30_15-43-56_UTC_4.jpg  CeMAqJ6M8dN  jacquemus            1
# 2  2022-05-30_15-43-56_UTC_5.jpg  CeMAqJ6M8dN  jacquemus            1
# 3  2022-05-30_15-43-56_UTC_2.jpg  CeMAqJ6M8dN  jacquemus            0
# 4  2022-05-30_15-43-56_UTC_1.jpg  CeMAqJ6M8dN  jacquemus            1
#
#                                       text_sup_clean  \
# 0  jacquemus sydney in hawai i at night by tom a ...
# 1  jacquemus sydney in hawai i at night by tom a ...
# 2  jacquemus sydney in hawai i at night by tom a ...
# 3  jacquemus sydney in hawai i at night by tom a ...
# 4  jacquemus sydney in hawai i at night by tom a ...
#
#                                      text_deep_clean  \
# 0  jacquemus sydney hawai i night tom woman long ...
# 1  jacquemus sydney hawai i night tom woman long ...
# 2  jacquemus sydney hawai i night tom woman long ...
# 3  jacquemus sydney hawai i night tom woman long ...
# 4  jacquemus sydney hawai i night tom woman long ...
#
#                                  text_deep_clean_pos hashtags
# 0  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 1  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 2  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 3  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 4  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []

# %% [markdown]
# Captions

# %%
# superficial cleaning
df['text_sup_clean_caption'] = df['caption'].apply(superficial_cleaning)

# deep cleaning
POS_KEEP = ["ADJ","ADV","NOUN","PROPN","VERB","NUM"] # we do not include "PRON"
df['text_deep_clean_caption'] = df['text_sup_clean_caption'].apply(deep_cleaning)
df['text_deep_clean_pos_caption'] = df['text_sup_clean_caption'].apply(deep_cleaning_pos)

# extract hashtags (if present)
df['hashtags_caption'] = df['caption'].apply(get_hashtags)
# Out:
# C:\Users\danie\Documents\GitHub\network_science\labs\cleaning_mod.py:156: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(selftext, "html.parser")

# %% [markdown]
# Autocaptions

# %%
# superficial cleaning
df['text_sup_clean_auto'] = df['Auto_caption'].apply(superficial_cleaning)

# deep cleaning
POS_KEEP = ["ADJ","ADV","NOUN","PROPN","VERB","NUM"] # we do not include "PRON"
df['text_deep_clean_auto'] = df['text_sup_clean_auto'].apply(deep_cleaning)
df['text_deep_clean_pos_auto'] = df['text_sup_clean_auto'].apply(deep_cleaning_pos)

# extract hashtags (if present)
#df['hashtags_auto'] = df['auto'].apply(get_hashtags)
# Out:
# C:\Users\danie\Documents\GitHub\network_science\labs\cleaning_mod.py:156: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(selftext, "html.parser")

# %%
df.head()
# Out:
#                                             post_dir  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                         Auto_caption  \
# 0  a woman with long brown hair sitting on a moto...
# 1  a woman with long brown hair sitting on a moto...
# 2  a woman with long brown hair sitting on a moto...
# 3  a woman with long brown hair sitting on a moto...
# 4  a woman with long brown hair sitting on a moto...
#
#                                                posts  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                              caption  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             All_text  \
# 0  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 1  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 2  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 3  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 4  jacquemus Sydney in Hawai’i at night by Tom\n@...
#
#                                             img_path  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                         img_name        short       user  objectifies  ...  \
# 0  2022-05-30_15-43-56_UTC_3.jpg  CeMAqJ6M8dN  jacquemus            1  ...
# 1  2022-05-30_15-43-56_UTC_4.jpg  CeMAqJ6M8dN  jacquemus            1  ...
# 2  2022-05-30_15-43-56_UTC_5.jpg  CeMAqJ6M8dN  jacquemus            1  ...
# 3  2022-05-30_15-43-56_UTC_2.jpg  CeMAqJ6M8dN  jacquemus            0  ...
# 4  2022-05-30_15-43-56_UTC_1.jpg  CeMAqJ6M8dN  jacquemus            1  ...
#
#                                      text_deep_clean  \
# 0  jacquemus sydney hawai i night tom woman long ...
# 1  jacquemus sydney hawai i night tom woman long ...
# 2  jacquemus sydney hawai i night tom woman long ...
# 3  jacquemus sydney hawai i night tom woman long ...
# 4  jacquemus sydney hawai i night tom woman long ...
#
#                                  text_deep_clean_pos hashtags  \
# 0  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 1  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 2  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 3  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
# 4  [jacquemus PROPN, sydney PROPN, hawai PROPN, i...       []
#
#                text_sup_clean_caption   text_deep_clean_caption  \
# 0  sydney in hawai i at night by tom   sydney hawai i night tom
# 1  sydney in hawai i at night by tom   sydney hawai i night tom
# 2  sydney in hawai i at night by tom   sydney hawai i night tom
# 3  sydney in hawai i at night by tom   sydney hawai i night tom
# 4  sydney in hawai i at night by tom   sydney hawai i night tom
#
#                          text_deep_clean_pos_caption hashtags_caption  \
# 0  [sydney PROPN, hawai PROPN, i PROPN, night NOU...               []
# 1  [sydney PROPN, hawai PROPN, i PROPN, night NOU...               []
# 2  [sydney PROPN, hawai PROPN, i PROPN, night NOU...               []
# 3  [sydney PROPN, hawai PROPN, i PROPN, night NOU...               []
# 4  [sydney PROPN, hawai PROPN, i PROPN, night NOU...               []
#
#                                  text_sup_clean_auto  \
# 0  a woman with long brown hair sitting on a moto...
# 1  a woman with long brown hair sitting on a moto...
# 2  a woman with long brown hair sitting on a moto...
# 3  a woman with long brown hair sitting on a moto...
# 4  a woman with long brown hair sitting on a moto...
#
#                                 text_deep_clean_auto  \
# 0  woman long brown hair sit motorcycle woman lon...
# 1  woman long brown hair sit motorcycle woman lon...
# 2  woman long brown hair sit motorcycle woman lon...
# 3  woman long brown hair sit motorcycle woman lon...
# 4  woman long brown hair sit motorcycle woman lon...
#
#                             text_deep_clean_pos_auto
# 0  [woman NOUN, long ADJ, brown ADJ, hair NOUN, s...
# 1  [woman NOUN, long ADJ, brown ADJ, hair NOUN, s...
# 2  [woman NOUN, long ADJ, brown ADJ, hair NOUN, s...
# 3  [woman NOUN, long ADJ, brown ADJ, hair NOUN, s...
# 4  [woman NOUN, long ADJ, brown ADJ, hair NOUN, s...
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['post_dir', 'Auto_caption', 'posts', 'caption', 'All_text', 'img_path',
#        'img_name', 'short', 'user', 'objectifies', 'text_sup_clean',
#        'text_deep_clean', 'text_deep_clean_pos', 'hashtags',
#        'text_sup_clean_caption', 'text_deep_clean_caption',
#        'text_deep_clean_pos_caption', 'hashtags_caption',
#        'text_sup_clean_auto', 'text_deep_clean_auto',
#        'text_deep_clean_pos_auto'],
#       dtype='object')

# %%
df_save = df[['post_dir', 'img_path','objectifies','text_deep_clean_caption','text_deep_clean_auto','text_deep_clean']].copy()
df_save.columns = ['post_dir', 'img_path','objectifies', 'clean_caption', 'clean_autocaption', 'clean_all']
df_save.head()
# Out:
#                                             post_dir  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                             img_path  objectifies  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...            1
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...            1
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...            1
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...            0
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...            1
#
#               clean_caption  \
# 0  sydney hawai i night tom
# 1  sydney hawai i night tom
# 2  sydney hawai i night tom
# 3  sydney hawai i night tom
# 4  sydney hawai i night tom
#
#                                    clean_autocaption  \
# 0  woman long brown hair sit motorcycle woman lon...
# 1  woman long brown hair sit motorcycle woman lon...
# 2  woman long brown hair sit motorcycle woman lon...
# 3  woman long brown hair sit motorcycle woman lon...
# 4  woman long brown hair sit motorcycle woman lon...
#
#                                            clean_all
# 0  jacquemus sydney hawai i night tom woman long ...
# 1  jacquemus sydney hawai i night tom woman long ...
# 2  jacquemus sydney hawai i night tom woman long ...
# 3  jacquemus sydney hawai i night tom woman long ...
# 4  jacquemus sydney hawai i night tom woman long ...

# %%
# store the results
out_dir = "../0_data/silver/"
out_file = "7_text"
df.to_excel(out_dir+out_file+"_clean_short.xlsx", index=True)

# %%
# store the results
'''out_dir = "../0_data/silver/"
out_file = "7_text"
df.to_excel(out_dir+out_file+"_clean_large.xlsx", index=True)'''
# Out:
# 'out_dir = "../0_data/silver/"\nout_file = "7_text"\ndf.to_excel(out_dir+out_file+"_clean_large.xlsx", index=True)'

# %% [markdown]
# # **Build an occurrence matrix for words and hashtags**

# %%
# store the results
dir = "../0_data/silver/"
file = "7_text"
df = pd.read_excel(dir+file+"_clean_short.xlsx")
df.rename(columns={'Unnamed: 0':'id'}, inplace = True)
df.head()
# Out:
#    id                                           post_dir  \
# 0   0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1   1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2   2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3   3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4   4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                         Auto_caption  \
# 0  a woman with long brown hair sitting on a moto...
# 1  a woman with long brown hair sitting on a moto...
# 2  a woman with long brown hair sitting on a moto...
# 3  a woman with long brown hair sitting on a moto...
# 4  a woman with long brown hair sitting on a moto...
#
#                                                posts  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                                              caption  \
# 0  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 1  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 2  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 3  Sydney in Hawai’i at night by Tom\n@sydney_swe...
# 4  Sydney in Hawai’i at night by Tom\n@sydney_swe...
#
#                                             All_text  \
# 0  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 1  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 2  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 3  jacquemus Sydney in Hawai’i at night by Tom\n@...
# 4  jacquemus Sydney in Hawai’i at night by Tom\n@...
#
#                                             img_path  \
# 0  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 1  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 2  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 3  ../1_download_data/jacquemus\2022-05-30_15-43-...
# 4  ../1_download_data/jacquemus\2022-05-30_15-43-...
#
#                         img_name        short       user  ...  \
# 0  2022-05-30_15-43-56_UTC_3.jpg  CeMAqJ6M8dN  jacquemus  ...
# 1  2022-05-30_15-43-56_UTC_4.jpg  CeMAqJ6M8dN  jacquemus  ...
# 2  2022-05-30_15-43-56_UTC_5.jpg  CeMAqJ6M8dN  jacquemus  ...
# 3  2022-05-30_15-43-56_UTC_2.jpg  CeMAqJ6M8dN  jacquemus  ...
# 4  2022-05-30_15-43-56_UTC_1.jpg  CeMAqJ6M8dN  jacquemus  ...
#
#                                      text_deep_clean  \
# 0  jacquemus sydney hawai i night tom woman long ...
# 1  jacquemus sydney hawai i night tom woman long ...
# 2  jacquemus sydney hawai i night tom woman long ...
# 3  jacquemus sydney hawai i night tom woman long ...
# 4  jacquemus sydney hawai i night tom woman long ...
#
#                                  text_deep_clean_pos hashtags  \
# 0  ['jacquemus PROPN', 'sydney PROPN', 'hawai PRO...       []
# 1  ['jacquemus PROPN', 'sydney PROPN', 'hawai PRO...       []
# 2  ['jacquemus PROPN', 'sydney PROPN', 'hawai PRO...       []
# 3  ['jacquemus PROPN', 'sydney PROPN', 'hawai PRO...       []
# 4  ['jacquemus PROPN', 'sydney PROPN', 'hawai PRO...       []
#
#                text_sup_clean_caption   text_deep_clean_caption  \
# 0  sydney in hawai i at night by tom   sydney hawai i night tom
# 1  sydney in hawai i at night by tom   sydney hawai i night tom
# 2  sydney in hawai i at night by tom   sydney hawai i night tom
# 3  sydney in hawai i at night by tom   sydney hawai i night tom
# 4  sydney in hawai i at night by tom   sydney hawai i night tom
#
#                          text_deep_clean_pos_caption hashtags_caption  \
# 0  ['sydney PROPN', 'hawai PROPN', 'i PROPN', 'ni...               []
# 1  ['sydney PROPN', 'hawai PROPN', 'i PROPN', 'ni...               []
# 2  ['sydney PROPN', 'hawai PROPN', 'i PROPN', 'ni...               []
# 3  ['sydney PROPN', 'hawai PROPN', 'i PROPN', 'ni...               []
# 4  ['sydney PROPN', 'hawai PROPN', 'i PROPN', 'ni...               []
#
#                                  text_sup_clean_auto  \
# 0  a woman with long brown hair sitting on a moto...
# 1  a woman with long brown hair sitting on a moto...
# 2  a woman with long brown hair sitting on a moto...
# 3  a woman with long brown hair sitting on a moto...
# 4  a woman with long brown hair sitting on a moto...
#
#                                 text_deep_clean_auto  \
# 0  woman long brown hair sit motorcycle woman lon...
# 1  woman long brown hair sit motorcycle woman lon...
# 2  woman long brown hair sit motorcycle woman lon...
# 3  woman long brown hair sit motorcycle woman lon...
# 4  woman long brown hair sit motorcycle woman lon...
#
#                             text_deep_clean_pos_auto
# 0  ['woman NOUN', 'long ADJ', 'brown ADJ', 'hair ...
# 1  ['woman NOUN', 'long ADJ', 'brown ADJ', 'hair ...
# 2  ['woman NOUN', 'long ADJ', 'brown ADJ', 'hair ...
# 3  ['woman NOUN', 'long ADJ', 'brown ADJ', 'hair ...
# 4  ['woman NOUN', 'long ADJ', 'brown ADJ', 'hair ...
#
# [5 rows x 22 columns]

# %%
# collection of words
words = np.unique([item for sublist in df['text_deep_clean_pos'] for item in sublist])
# words dictionary
words_dict = dict(zip(words,range(len(words))))
# occurrence matrix for words
Mwd = csr_matrix((len(words_dict), len(df)), dtype = np.int8).toarray()
for i in range(len(df)):
  for j in df['text_deep_clean_pos'][i]:
    Mwd[words_dict[j],i] += 1

# %%
# collection of hashtags
hashtags = np.unique([item for sublist in df['hashtags'] for item in sublist])
# add the # sign
hashtags2 = np.unique(["#"+item for sublist in df['hashtags'] for item in sublist])
# hashtags dictionary
hashtags_dict = dict(zip(hashtags,range(len(hashtags))))
# occurrence matrix for hashtags
Mhd = csr_matrix((len(hashtags_dict), len(df)), dtype = np.int8).toarray()
for i in range(len(df)):
  for j in df['hashtags'][i]:
    Mhd[hashtags_dict[j],i] += 1

# %%
# join words and hashtags
Mwd = np.vstack((Mwd, Mhd)) # in one occurrence matrix
words = np.hstack((words, hashtags2)) # in one word+hashtags list
documents = np.array(df["id"].tolist()) # further collect documents names

# %% [markdown]
# # **Remove least occurring words**

# %%
# display word occurrences first
plt.figure()
plt.semilogy(-np.sort(-np.sum(Mwd,axis=1)))
plt.savefig(out_dir+out_file+"_statistics.png")

# %%
# remove words that are used once or twice
select = (np.sum(Mwd,axis=1)>2)
Mwd = Mwd[select,:]
words = words[select]
# remove documents that do not contain words
select = (np.sum(Mwd,axis=0)>0)
Mwd = Mwd[:,select]
documents = documents[select]
# display final matrix size
display(Mwd.shape)
# Out:
# (79, 1587)

# %%
# store the result
out_dir = "../0_data/silver/"
out_file = "7_text"
pickle.dump([Mwd,words,documents], open(out_dir+out_file+"_occurrences_short.p", "wb"))
# c,d,e = pickle.load(open(out_dir+out_file+"_occurrences.p","rb"))
